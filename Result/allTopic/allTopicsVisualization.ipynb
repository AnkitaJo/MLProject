# %%
import gensim

dictionary = gensim.corpora.Dictionary.load('allDictionarySave.dict')
corpus = gensim.corpora.MmCorpus('allCorpusSave.mm')
lda = gensim.models.ldamodel.LdaModel.load('allSampleModel.model')

# %%
import pyLDAvis.gensim
vis_data = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(vis_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el42574387177936808035592"></div>
# <script type="text/javascript">
#
# ...
