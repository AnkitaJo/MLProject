# %%
import gensim

dictionary = gensim.corpora.Dictionary.load('cruzDictionarySave.dict')
corpus = gensim.corpora.MmCorpus('cruzCorpusSave.mm')
lda = gensim.models.ldamodel.LdaModel.load('cruzSampleModel.model')

# %%
import pyLDAvis.gensim
vis_data = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(vis_data)
# Out:
# /Users/admin/Documents/pythonworkspace/notebooks/venv/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/admin/Documents/pythonworkspace/notebooks/venv/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /Users/admin/Documents/pythonworkspace/notebooks/venv/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# ...
