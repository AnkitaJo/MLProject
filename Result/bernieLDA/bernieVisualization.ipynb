# %%
import gensim

dictionary = gensim.corpora.Dictionary.load('bernieDictionarySave.dict')
corpus = gensim.corpora.MmCorpus('bernieCorpusSave.mm')
lda = gensim.models.ldamodel.LdaModel.load('bernieSampleModel.model')

# %%
import pyLDAvis.gensim
vis_data = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(vis_data)
# Out:
# /Users/admin/Documents/pythonworkspace/notebooks/venv/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /Users/admin/Documents/pythonworkspace/notebooks/venv/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:102: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00489851054698 and the largest is 0.327035005545.
#   RuntimeWarning
# ...
